# %%
import sys
sys.path.insert(0,'../../') # adds parent directory

import numpy as np
import pde
import scipy.sparse as sps
import time
import ngsolve as ng
from sksparse.cholmod import cholesky as chol

# %% [markdown]
# # This should be large
#
# This is $\pi$

# %%
motor_npz = np.load('../meshes/motor.npz', allow_pickle = True)

geoOCC = motor_npz['geoOCC'].tolist()
m = motor_npz['m']; m_new = m
j3 = motor_npz['j3']

geoOCCmesh = geoOCC.GenerateMesh()
ngsolve_mesh = ng.Mesh(geoOCCmesh)
# ngsolve_mesh.Refine()
# ngsolve_mesh.Refine()

nu0 = 10**7/(4*np.pi)
MESH = pde.mesh.netgen(ngsolve_mesh.ngmesh)

linear = '*air,*magnet,shaft_iron,*coil'
nonlinear = 'stator_iron,rotor_iron'
rotor = 'rotor_iron,*magnet,rotor_air,shaft_iron'

# %%
space_Vh = 'N0'
space_Qh = 'P0'
# space_Qh = 'P1_orth_divN1'
int_order = 2

tm = time.monotonic()

phi_Hcurl = lambda x : pde.hcurl.assemble(MESH, space = space_Vh, matrix = 'phi', order = x)
curlphi_Hcurl = lambda x : pde.hcurl.assemble(MESH, space = space_Vh, matrix = 'curlphi', order = x)
phi_L2 = lambda x : pde.l2.assemble(MESH, space = space_Qh, matrix = 'M', order = x)

D = lambda x : pde.int.assemble(MESH, order = x)

Mh = lambda x: phi_Hcurl(x)[0] @ D(x) @ phi_Hcurl(x)[0].T + \
               phi_Hcurl(x)[1] @ D(x) @ phi_Hcurl(x)[1].T

D1 = D(1); D2 = D(2); D4 = D(4); Mh1 = Mh(1); Mh2 = Mh(2)
D_int_order = D(int_order)

phi_L2_o1 = phi_L2(1)
curlphi_Hcurl_o1 = curlphi_Hcurl(1)

phix_Hcurl = phi_Hcurl(int_order)[0];
phiy_Hcurl = phi_Hcurl(int_order)[1];


inv = lambda x : pde.tools.fastBlockInverse(x)

C = phi_L2(int_order) @ D(int_order) @ curlphi_Hcurl(int_order).T


fem_linear = pde.int.evaluate(MESH, order = int_order, regions = linear).diagonal()
fem_nonlinear = pde.int.evaluate(MESH, order = int_order, regions = nonlinear).diagonal()
fem_rotor = pde.int.evaluate(MESH, order = int_order, regions = rotor).diagonal()
fem_air_gap_rotor = pde.int.evaluate(MESH, order = int_order, regions = 'air_gap_rotor').diagonal()

Ja = 0; J0 = 0
for i in range(48):
    Ja += pde.int.evaluate(MESH, order = int_order, coeff = lambda x,y : j3[i], regions = 'coil'+str(i+1)).diagonal()
    J0 += pde.int.evaluate(MESH, order = 0, coeff = lambda x,y : j3[i], regions = 'coil'+str(i+1)).diagonal()
Ja = 0*Ja
J0 = 0*J0

M0 = 0; M1 = 0; M00 = 0; M10 = 0
for i in range(16):
    M0 += pde.int.evaluate(MESH, order = int_order, coeff = lambda x,y : m_new[0,i], regions = 'magnet'+str(i+1)).diagonal()
    M1 += pde.int.evaluate(MESH, order = int_order, coeff = lambda x,y : m_new[1,i], regions = 'magnet'+str(i+1)).diagonal()
    
    M00 += pde.int.evaluate(MESH, order = 0, coeff = lambda x,y : m_new[0,i], regions = 'magnet'+str(i+1)).diagonal()
    M10 += pde.int.evaluate(MESH, order = 0, coeff = lambda x,y : m_new[1,i], regions = 'magnet'+str(i+1)).diagonal()

# %%
space_Vhd = 'N0d'

phix_d_Hcurl,phiy_d_Hcurl = pde.hcurl.assemble(MESH, space = space_Vhd, matrix = 'phi', order = int_order)
curlphi_d_Hcurl = pde.hcurl.assemble(MESH, space = space_Vhd, matrix = 'curlphi', order = int_order)

Md = phix_d_Hcurl @ D(int_order) @ phix_d_Hcurl.T +\
     phiy_d_Hcurl @ D(int_order) @ phiy_d_Hcurl.T
iMd = pde.tools.fastBlockInverse(Md)

iMd.data = iMd.data*(np.abs(iMd.data)>1e-7)
iMd.eliminate_zeros()

Cd = phi_L2(int_order) @ D(int_order) @ curlphi_d_Hcurl.T

aMd = phix_d_Hcurl@ D(int_order) @(M0) +\
      phiy_d_Hcurl@ D(int_order) @(M1)

R0,R1,R2 = pde.hcurl.assembleE(MESH, space = space_Vhd, matrix = 'M', order = 2)

phi_e = pde.l2.assembleE(MESH, space = 'P0', matrix = 'M', order = 1)

De = pde.int.assembleE(MESH, order = 1)
KK = phi_e @ De @ (R0+R1+R2).T

# KK = KK[np.r_[2*MESH.NonSingle_Edges,\
#               2*MESH.NonSingle_Edges+1],:]

KK = KK[MESH.NonSingle_Edges,:]
# Out:
# Preparing lists 0.01574707 seconds.
# Took 0.08127618 seconds.

# %%
from nonlinLaws import *

sH = phix_d_Hcurl.shape[0]
sA = phi_L2_o1.shape[0]
sL = KK.shape[0]

mu0 = (4*np.pi)/10**7
H = 1e-2+np.zeros(sH)
A = 0+np.zeros(sA)
L = 0+np.zeros(sL)

HAL = np.r_[H,A,L]


def gs_hybrid(allH,A,H,L):
    gx_H_l  = allH[1]; gy_H_l  = allH[2];
    gx_H_nl = allH[8]; gy_H_nl = allH[9];
    
    r1 = phix_d_Hcurl @ D_int_order @ (gx_H_l*fem_linear + gx_H_nl*fem_nonlinear + mu0*M0) +\
         phiy_d_Hcurl @ D_int_order @ (gy_H_l*fem_linear + gy_H_nl*fem_nonlinear + mu0*M1) + Cd.T@A +KK.T@L
    r2 = Cd@H
    r3 = KK@H
    
    # r = -KK@iMd@r1 + KK@iMd@Cd.T@iBBd@(Cd@iMd@r1-r2)
    
    return np.r_[r1,r2,r3]

def J(allH,H):
    g_H_l = allH[0]; g_H_nl = allH[7];
    return np.ones(D_int_order.size)@ D_int_order @(g_H_l*fem_linear + g_H_nl*fem_nonlinear) + mu0*aMd@H


maxIter = 100
epsangle = 1e-5;

angleCondition = np.zeros(5)
eps_newton = 1e-12
factor_residual = 1/2
mu = 0.0001

tm1 = time.monotonic()
for i in range(maxIter):
    
    H = HAL[:sH]
    A = HAL[sH:sH+sA]
    L = HAL[sH+sA:]
    
    ##########################################################################################
    Hx = phix_d_Hcurl.T@H; Hy = phiy_d_Hcurl.T@H
    
    tm = time.monotonic()
    allH = g_nonlinear_all(Hx,Hy)
    
    print('Evaluating nonlinearity took ', time.monotonic()-tm)
    
    tm = time.monotonic()
    gxx_H_l  = allH[3];  gxy_H_l  = allH[4];  gyx_H_l  = allH[5];  gyy_H_l  = allH[6];
    gxx_H_nl = allH[10]; gxy_H_nl = allH[11]; gyx_H_nl = allH[12]; gyy_H_nl = allH[13];
    
    gxx_H_Mxx = phix_d_Hcurl @ D_int_order @ sps.diags(gxx_H_nl*fem_nonlinear + gxx_H_l*fem_linear)@ phix_d_Hcurl.T
    gyy_H_Myy = phiy_d_Hcurl @ D_int_order @ sps.diags(gyy_H_nl*fem_nonlinear + gyy_H_l*fem_linear)@ phiy_d_Hcurl.T
    gxy_H_Mxy = phiy_d_Hcurl @ D_int_order @ sps.diags(gxy_H_nl*fem_nonlinear + gxy_H_l*fem_linear)@ phix_d_Hcurl.T
    gyx_H_Myx = phix_d_Hcurl @ D_int_order @ sps.diags(gyx_H_nl*fem_nonlinear + gyx_H_l*fem_linear)@ phiy_d_Hcurl.T
    
    Md = gxx_H_Mxx + gyy_H_Myy + gxy_H_Mxy + gyx_H_Myx
    
    gx_H_l  = allH[1]; gy_H_l  = allH[2]; gx_H_nl = allH[8]; gy_H_nl = allH[9];
    
    r1 = phix_d_Hcurl @ D_int_order @ (gx_H_l*fem_linear + gx_H_nl*fem_nonlinear + mu0*M0) +\
         phiy_d_Hcurl @ D_int_order @ (gy_H_l*fem_linear + gy_H_nl*fem_nonlinear + mu0*M1) + Cd.T@A + KK.T@L
    r2 = Cd@H
    r3 = KK@H
    
    print('Assembling took ', time.monotonic()-tm)
    
    
    
    tm = time.monotonic()
    iMd = inv(Md)
    iBBd = inv(Cd@iMd@Cd.T)
    print('Inverting took ', time.monotonic()-tm)
    
    
    
    tm = time.monotonic()
    gssuR = -KK@iMd@KK.T + KK@iMd@Cd.T@iBBd@Cd@iMd@KK.T
    gsuR = -(KK@iMd@r1-r3) + KK@iMd@Cd.T@iBBd@(Cd@iMd@r1-r2)
    print('Multiplication took ', time.monotonic()-tm)
    
    
    
    tm = time.monotonic()
    wL = chol(-gssuR).solve_A(gsuR)
    print('Solving the system took ', time.monotonic()-tm)
    
    # tm = time.monotonic()
    # wL = sps.linalg.spsolve(-gssuR,gsuR)
    # print('Solving the system took ', time.monotonic()-tm)
    
    wA = iBBd@Cd@iMd@(-r1-KK.T@wL)+iBBd@r2
    wH = iMd@(-Cd.T@wA-KK.T@wL-r1)
    w = np.r_[wH,wA,wL]
    
    gsu = gs_hybrid(allH,A,H,L)
    
    ##########################################################################################
    
    
    
    norm_w = np.linalg.norm(w)
    norm_gsu = np.linalg.norm(gsu)
    
    if (-(w@gsu)/(norm_w*norm_gsu)<epsangle):
        angleCondition[i%5] = 1
        if np.product(angleCondition)>0:
            w = -gsu
            print("STEP IN NEGATIVE GRADIENT DIRECTION")
            break
    else: angleCondition[i%5]=0
    
    alpha = 1
    
    # ResidualLineSearch
    # for k in range(1000):
        
    #     HAu = HA + alpha*w
    #     Hu = HAu[:2*MESH.NoEdges]
    #     Au = HAu[2*MESH.NoEdges:]
        
    #     Hxu = phix_Hcurl.T@(Hu)
    #     Hyu = phiy_Hcurl.T@(Hu)
        
    #     allHu = g_nonlinear_all(Hxu,Hyu)
        
    #     if np.linalg.norm(gs(allHu,Au,Hu)) <= np.linalg.norm(gs(allH,A,H)): break
    #     else: alpha = alpha*factor_residual
    
    # AmijoBacktracking
    
    tm = time.monotonic()
    float_eps = 1e-8 #np.finfo(float).eps
    for kk in range(1000):
        
        HALu = HAL + alpha*w
        Hu = HALu[:sH]
        
        Hxu = phix_d_Hcurl.T@Hu; Hyu = phiy_d_Hcurl.T@Hu;
        allHu = g_nonlinear_all(Hxu,Hyu)
        
        if J(allHu,Hu)-J(allH,H) <= alpha*mu*(gsu@w) + np.abs(J(allH,H))*float_eps: break
        else: alpha = alpha*factor_residual
        
    print('Line search took ', time.monotonic()-tm)
    
    HAL = HALu; H = Hu; Hx = Hxu; Hy = Hyu; allH = allHu
    
    print ("NEWTON: Iteration: %2d " %(i+1)+"||obj: %2e" %J(allH,H)+"|| ||grad||: %2e" %np.linalg.norm(gs_hybrid(allH,A,H,L),np.inf)+"||alpha: %2e" % (alpha)); print("\n")
    if(np.linalg.norm(gs_hybrid(allH,A,H,L),np.inf) < eps_newton): break

elapsed = time.monotonic()-tm1
print('Solving took ', elapsed, 'seconds')
# Out:
# Evaluating nonlinearity took  0.42478768806904554
# Assembling took  0.35152052401099354
# Preparing lists 0.01383495 seconds.
# Took 0.08272576 seconds.
# Preparing lists 0.00307322 seconds.
# Took 0.07394099 seconds.
# Inverting took  0.4303045690758154
# Multiplication took  0.32118131895549595
# Solving the system took  0.2868811039952561
# Line search took  0.4649508000584319
# NEWTON: Iteration:  1 ||obj: -8.315635e+00|| ||grad||: 1.009286e-03||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.4189629149623215
# Assembling took  0.33770237502176315
# Preparing lists 0.00977731 seconds.
# Took 0.08123183 seconds.
# Preparing lists 0.00301909 seconds.
# Took 0.07323718 seconds.
# Inverting took  0.44779561005998403
# Multiplication took  0.3123968589352444
# Solving the system took  0.2916595370043069
# Line search took  0.5352510139346123
# NEWTON: Iteration:  2 ||obj: -2.890172e+01|| ||grad||: 2.014959e-03||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.47680320602376014
# Assembling took  0.37316309299785644
# Preparing lists 0.01397181 seconds.
# Took 0.07800198 seconds.
# Preparing lists 0.00611687 seconds.
# Took 0.07141685 seconds.
# Inverting took  0.4411016219528392
# Multiplication took  0.2942726709879935
# Solving the system took  0.2681274509523064
# Line search took  0.5346389530459419
# NEWTON: Iteration:  3 ||obj: -3.426971e+01|| ||grad||: 1.491600e-03||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.48678749601822346
# Assembling took  0.34602392208762467
# Preparing lists 0.01022124 seconds.
# Took 0.08089185 seconds.
# Preparing lists 0.00893688 seconds.
# Took 0.07125211 seconds.
# Inverting took  0.42140249896328896
# Multiplication took  0.3300442569889128
# Solving the system took  0.2536852180492133
# Line search took  1.016233642003499
# NEWTON: Iteration:  4 ||obj: -3.495201e+01|| ||grad||: 9.751889e-04||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.4613837150391191
# Assembling took  0.37783162004780024
# Preparing lists 0.01189280 seconds.
# Took 0.07971311 seconds.
# Preparing lists 0.00375509 seconds.
# Took 0.07202291 seconds.
# Inverting took  0.4091860819607973
# Multiplication took  0.30514054896775633
# Solving the system took  0.2751931819366291
# Line search took  1.1043115759966895
# NEWTON: Iteration:  5 ||obj: -3.504128e+01|| ||grad||: 1.167961e-03||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.6052800139877945
# Assembling took  0.40057976299431175
# Preparing lists 0.01827407 seconds.
# Took 0.08061099 seconds.
# Preparing lists 0.00305486 seconds.
# Took 0.07410622 seconds.
# Inverting took  0.44480818102601916
# Multiplication took  0.32061597204301506
# Solving the system took  0.25730419799219817
# Line search took  0.9902194370515645
# NEWTON: Iteration:  6 ||obj: -3.527287e+01|| ||grad||: 6.502359e-04||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.4621301650768146
# Assembling took  0.33446924202144146
# Preparing lists 0.01186991 seconds.
# Took 0.07877231 seconds.
# Preparing lists 0.00467825 seconds.
# Took 0.07378817 seconds.
# Inverting took  0.44553140504285693
# Multiplication took  0.3203450820874423
# Solving the system took  0.2534845160553232
# Line search took  0.9392266389913857
# NEWTON: Iteration:  7 ||obj: -3.531191e+01|| ||grad||: 9.207783e-04||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.43856888404116035
# Assembling took  0.3918429909972474
# Preparing lists 0.01095080 seconds.
# Took 0.08014703 seconds.
# Preparing lists 0.00589108 seconds.
# Took 0.07207298 seconds.
# Inverting took  0.44753402296919376
# Multiplication took  0.30465391697362065
# Solving the system took  0.25664376304484904
# Line search took  1.175076673971489
# NEWTON: Iteration:  8 ||obj: -3.534201e+01|| ||grad||: 4.158289e-04||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.5963395179715008
# Assembling took  0.3777406649896875
# Preparing lists 0.01158905 seconds.
# Took 0.08047605 seconds.
# Preparing lists 0.00292706 seconds.
# Took 0.07849407 seconds.
# Inverting took  0.43147260800469667
# Multiplication took  0.30223301495425403
# Solving the system took  0.2936280050780624
# Line search took  1.2639839639887214
# NEWTON: Iteration:  9 ||obj: -3.535621e+01|| ||grad||: 4.302166e-04||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.615803500986658
# Assembling took  0.34932548191864043
# Preparing lists 0.01808524 seconds.
# Took 0.07886791 seconds.
# Preparing lists 0.00401998 seconds.
# Took 0.07151389 seconds.
# Inverting took  0.4407727250363678
# Multiplication took  0.3003645879216492
# Solving the system took  0.26315773592796177
# Line search took  0.5282729209866375
# NEWTON: Iteration: 10 ||obj: -3.536006e+01|| ||grad||: 2.256877e-04||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.47017471003346145
# Assembling took  0.3148061400279403
# Preparing lists 0.01190877 seconds.
# Took 0.07860589 seconds.
# Preparing lists 0.00290298 seconds.
# Took 0.07411408 seconds.
# Inverting took  0.4212689340347424
# Multiplication took  0.32669749204069376
# Solving the system took  0.268484159023501
# Line search took  0.9909545319387689
# NEWTON: Iteration: 11 ||obj: -3.536014e+01|| ||grad||: 1.153521e-04||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.46329517394769937
# Assembling took  0.34515815402846783
# Preparing lists 0.00895619 seconds.
# Took 0.07829499 seconds.
# Preparing lists 0.00605416 seconds.
# Took 0.07201695 seconds.
# Inverting took  0.43355806404724717
# Multiplication took  0.33007715304847807
# Solving the system took  0.2789699489949271
# Line search took  1.5131510429782793
# NEWTON: Iteration: 12 ||obj: -3.536030e+01|| ||grad||: 1.113829e-04||alpha: 2.500000e-01
#
#
# Evaluating nonlinearity took  0.46137250191532075
# Assembling took  0.3465877780690789
# Preparing lists 0.00942898 seconds.
# Took 0.07815790 seconds.
# Preparing lists 0.01293802 seconds.
# Took 0.07135105 seconds.
# Inverting took  0.43321614409796894
# Multiplication took  0.2755253880750388
# Solving the system took  0.25730936392210424
# Line search took  1.4758977940073237
# NEWTON: Iteration: 13 ||obj: -3.536038e+01|| ||grad||: 1.083801e-04||alpha: 2.500000e-01
#
#
# Evaluating nonlinearity took  0.46935080306138843
# Assembling took  0.33216266508679837
# Preparing lists 0.00929022 seconds.
# Took 0.08307314 seconds.
# Preparing lists 0.00744700 seconds.
# Took 0.07146692 seconds.
# Inverting took  0.4415190180297941
# Multiplication took  0.3361453659599647
# Solving the system took  0.24959396896883845
# Line search took  1.519544988987036
# NEWTON: Iteration: 14 ||obj: -3.536047e+01|| ||grad||: 9.775812e-05||alpha: 2.500000e-01
#
#
# Evaluating nonlinearity took  0.46151711989659816
# Assembling took  0.3618769650347531
# Preparing lists 0.01094103 seconds.
# Took 0.07859111 seconds.
# Preparing lists 0.00297308 seconds.
# Took 0.07141709 seconds.
# Inverting took  0.470451608998701
# Multiplication took  0.3047414349857718
# Solving the system took  0.25304132397286594
# Line search took  1.4762189710745588
# NEWTON: Iteration: 15 ||obj: -3.536055e+01|| ||grad||: 8.147422e-05||alpha: 2.500000e-01
#
#
# Evaluating nonlinearity took  0.46497151092626154
# Assembling took  0.34718247095588595
# Preparing lists 0.00947809 seconds.
# Took 0.07813525 seconds.
# Preparing lists 0.00499010 seconds.
# Took 0.07500601 seconds.
# Inverting took  0.41952902800403535
# Multiplication took  0.34866062295623124
# Solving the system took  0.29543059202842414
# Line search took  1.5201240440364927
# NEWTON: Iteration: 16 ||obj: -3.536063e+01|| ||grad||: 6.296294e-05||alpha: 2.500000e-01
#
#
# Evaluating nonlinearity took  0.47036366804968566
# Assembling took  0.35779309598729014
# Preparing lists 0.02006006 seconds.
# Took 0.07782602 seconds.
# Preparing lists 0.00310493 seconds.
# Took 0.07365799 seconds.
# Inverting took  0.4223551560426131
# Multiplication took  0.3448712220415473
# Solving the system took  0.25632426294032484
# Line search took  1.0391925929579884
# NEWTON: Iteration: 17 ||obj: -3.536067e+01|| ||grad||: 2.714818e-05||alpha: 5.000000e-01
#
#
# Evaluating nonlinearity took  0.4696982690365985
# Assembling took  0.33822079794481397
# Preparing lists 0.01020002 seconds.
# Took 0.07827210 seconds.
# Preparing lists 0.00732303 seconds.
# Took 0.07238078 seconds.
# Inverting took  0.43850183906033635
# Multiplication took  0.30597227497491986
# Solving the system took  0.25068872899282724
# Line search took  0.5120018350426108
# NEWTON: Iteration: 18 ||obj: -3.536067e+01|| ||grad||: 2.636388e-05||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.46760406089015305
# Assembling took  0.36256117990706116
# Preparing lists 0.01185584 seconds.
# Took 0.07877302 seconds.
# Preparing lists 0.00236011 seconds.
# Took 0.07419181 seconds.
# Inverting took  0.43947449896950275
# Multiplication took  0.31396553898230195
# Solving the system took  0.25069846003316343
# Line search took  0.535597734968178
# NEWTON: Iteration: 19 ||obj: -3.536067e+01|| ||grad||: 1.343409e-06||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.468101317062974
# Assembling took  0.34106610203161836
# Preparing lists 0.01206493 seconds.
# Took 0.07862878 seconds.
# Preparing lists 0.00253582 seconds.
# Took 0.07272506 seconds.
# Inverting took  0.4636613830225542
# Multiplication took  0.3183344140416011
# Solving the system took  0.2745203549275175
# Line search took  0.4997655500192195
# NEWTON: Iteration: 20 ||obj: -3.536067e+01|| ||grad||: 1.809225e-08||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.4695714929839596
# Assembling took  0.3236450230469927
# Preparing lists 0.01159239 seconds.
# Took 0.07846928 seconds.
# Preparing lists 0.01599383 seconds.
# Took 0.07015204 seconds.
# Inverting took  0.4657363189617172
# Multiplication took  0.33979384403210133
# Solving the system took  0.25690004194620997
# Line search took  0.5109827349660918
# NEWTON: Iteration: 21 ||obj: -3.536067e+01|| ||grad||: 1.041778e-11||alpha: 1.000000e+00
#
#
# Evaluating nonlinearity took  0.4584848750382662
# Assembling took  0.3428468119818717
# Preparing lists 0.01485801 seconds.
# Took 0.08107781 seconds.
# Preparing lists 0.01269913 seconds.
# Took 0.07612205 seconds.
# Inverting took  0.47358474507927895
# Multiplication took  0.34329333901405334
# Solving the system took  0.272385002928786
# Line search took  0.5206805770285428
# NEWTON: Iteration: 22 ||obj: -3.536067e+01|| ||grad||: 2.842171e-14||alpha: 1.000000e+00
#
#
# Solving took  67.26259170798585 seconds

# %%
# Torque computation
fem_linear = pde.int.evaluate(MESH, order = int_order, regions = linear).diagonal()
fem_nonlinear = pde.int.evaluate(MESH, order = int_order, regions = nonlinear).diagonal()

#outer radius rotor
r_outer = 78.63225*10**(-3);
#sliding mesh rotor
r_sliding = 78.8354999*10**(-3);
#sliding mesh stator
r_sliding2 = 79.03874999*10**(-3);
#inner radius stator
r_inner = 79.242*10**(-3);

r1 = r_outer
r2 = r_inner

# dazwischen = lambda x,y : 
scale = lambda x,y : 1*(x**2+y**2<r1**2)+(x**2+y**2-r2**2)/(r1**2-r2**2)*(x**2+y**2>r1**2)*(x**2+y**2<r2**2)
scalex = lambda x,y : (2*x)/(r1**2-r2**2)#*(x**2+y**2>r1**2)*(x**2+y**2<r2**2)
scaley = lambda x,y : (2*y)/(r1**2-r2**2)#*(x**2+y**2>r1**2)*(x**2+y**2<r2**2)

v = lambda x,y : np.r_[-y,x]*scale(x,y) # v wird nie wirklich gebraucht...

v1x = lambda x,y : -y*scalex(x,y)
v1y = lambda x,y : -scale(x,y)-y*scaley(x,y)
v2x = lambda x,y :  scale(x,y)+x*scalex(x,y)
v2y = lambda x,y :  x*scaley(x,y)

# ind_air_gaps = MESH.getIndices2d(regions_2d, 'air_gap', exact = 0, return_index = True)[0]

v1x_fem = pde.int.evaluate(MESH, order = int_order, coeff = v1x, regions = '*air_gap').diagonal()
v1y_fem = pde.int.evaluate(MESH, order = int_order, coeff = v1y, regions = '*air_gap').diagonal()
v2x_fem = pde.int.evaluate(MESH, order = int_order, coeff = v2x, regions = '*air_gap').diagonal()
v2y_fem = pde.int.evaluate(MESH, order = int_order, coeff = v2y, regions = '*air_gap').diagonal()

scale_fem = pde.int.evaluate(MESH, order = int_order, coeff = scale, regions = '*air_gap,'+rotor).diagonal()
one_fem = pde.int.evaluate(MESH, order = int_order, coeff = lambda x,y : 1+0*x+0*y, regions = '*air_gap,'+rotor).diagonal()

Hx = phix_d_Hcurl.T@H; Hy = phiy_d_Hcurl.T@H
gx_H_l  = allH[1]; gy_H_l  = allH[2]; gx_H_nl = allH[8]; gy_H_nl = allH[9]; g_H_l = allH[0]; g_H_nl = allH[7];

gHx = gx_H_l*fem_linear + gx_H_nl*fem_nonlinear + mu0*M0
gHy = gy_H_l*fem_linear + gy_H_nl*fem_nonlinear + mu0*M1

gH = g_H_l*fem_linear + g_H_nl*fem_nonlinear

# b1 = uy
# b2 = -ux
# fu = f(ux,uy)+1/2*(M0_dphi*uy-M1_dphi*ux)
# fbb1 =  fy(ux,uy)+M0_dphi
# fbb2 = -fx(ux,uy)+M1_dphi
# a_Pk = u_Pk

# term1 = (fu + fbb1*b1 +fbb2*b2 -Ja0*a_Pk)*(v1x_fem + v2y_fem)

# term2 = (fbb1*b1)*v1x_fem + \
#         (fbb2*b1)*v2x_fem + \
#         (fbb1*b2)*v1y_fem + \
#         (fbb2*b2)*v2y_fem


term1 = (gH +gHx*Hx +gHy*Hy)*(v1x_fem + v2y_fem)
term2 = (gHx*Hx)*v1x_fem + \
        (gHy*Hx)*v2x_fem + \
        (gHx*Hy)*v1y_fem + \
        (gHy*Hy)*v2y_fem


term_2 = -(term1+term2)
tor = one_fem@D_int_order@term_2
print('Torque:', tor)
# Out:
# Torque: -0.13298711403711738

# %%
# phix_d_Hcurl,phiy_d_Hcurl = pde.hcurl.assemble(MESH, space = space_Vhd, matrix = 'phi', order = 1)

# Hx = phix_d_Hcurl.T@H; Hy = phiy_d_Hcurl.T@H
# allH = g_nonlinear_all(Hx,Hy)
# gx_H_l  = allH[1]; gy_H_l  = allH[2];
# gx_H_nl = allH[8]; gy_H_nl = allH[9];

# fem_linear = pde.int.evaluate(MESH, order = 1, regions = linear).diagonal()
# fem_nonlinear = pde.int.evaluate(MESH, order = 1, regions = nonlinear).diagonal()

# Bx = (gx_H_l*fem_linear + gx_H_nl*fem_nonlinear)
# By = (gy_H_l*fem_linear + gy_H_nl*fem_nonlinear)

# fig = MESH.pdesurf(Bx**2+By**2, cmax = 5)

# fig.update_layout(height=1000)
# fig.show(renderer="iframe")
